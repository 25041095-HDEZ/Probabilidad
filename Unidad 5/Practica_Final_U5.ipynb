# %% [markdown]
# <a href="https://colab.research.google.com/github/25041095-HDEZ/Probabilidad/blob/main/Unidad%205/Practica_Final_U5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Probabilidad y Estadistica
#
# ### Unidad 5
#
# ### Facilitador: Jose Gabriel Rodriguez Rivas
#
# ### Alumno: Luis Arturo Tovar Hernández
#
# ### Practica Final de la Unidad 5

# %%
from scipy.stats import pearsonr
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import numpy as np
import seaborn as sns

# %% [markdown]
# ### **Grupo 1**
# ### Carga y exploracion de los datos.

# %%
df1 = pd.read_csv("grupo1.csv")
df1.head()
# Out:
#    HorasEstudio  Calificacion
# 0         20.00         75.94
# 1         15.60         87.48
# 2         17.91         79.40
# 3         20.00         73.37
# 4         20.00         83.75

# %%
df1.describe()
# Out:
#        HorasEstudio  Calificacion
# count     50.000000      50.00000
# mean      14.352000      83.78820
# std        4.219174       7.83389
# min        3.790000      68.46000
# 25%       12.032500      78.03500
# 50%       14.600000      84.49000
# 75%       17.715000      88.09000
# max       20.000000     100.00000

# %%
#Histograma de las calificaciones
plt.hist(df1["Calificacion"], bins=10, color="skyblue", edgecolor="black")
plt.title("Histograma Calificaciones Grupo 1")
plt.xlabel("Calificación")
plt.ylabel("Frecuencia")
plt.show()

# %% [markdown]
# ### Modelo de Regrecion Lineal

# %%
HorasGrupo1 = df1[["HorasEstudio"]]
CalificacionGrupo1 = df1["Calificacion"]

modeloGrupo1 = LinearRegression()
modeloGrupo1.fit(HorasGrupo1, CalificacionGrupo1)

print("Coeficiente de la pendiente (m):", modeloGrupo1.coef_[0])
print("Interpretación de la recta (b):", modeloGrupo1.intercept_)
# Out:
# Coeficiente de la pendiente (m): -0.10608151145860807
# Interpretación de la recta (b): 85.31068185245395

# %% [markdown]
# ###Visualización de resultados
#
# ###Grafico de dispersión y linea de regresión

# %%
# Datos Grupo 1
df1 = pd.read_csv("grupo1.csv")
horas_estudio1 = df1["HorasEstudio"].values.reshape(-1, 1)
calificaciones1 = df1["Calificacion"].values

# Definir tamaño
plt.figure(figsize=(6, 5))

# Crear el diagrama de dispersión con línea de regresión
sns.set(style="whitegrid")
sns.regplot(x=horas_estudio1, y=calificaciones1, scatter=True, color='blue')
plt.title('Diagrama de Dispersion con Línea de Regresión')
plt.xlabel('Horas de estudio')
plt.ylabel('Califiación')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Coeficiente de correlación de Peason

# %%
# Datos Grupo 1
df1 = pd.read_csv("grupo1.csv")
horas_estudio1 = df1["HorasEstudio"]
calificaciones1 = df1["Calificacion"]

# Calcular coeficiente de correlación de Pearson
coef_corr1, valor_p1 = pearsonr(horas_estudio1, calificaciones1)

print("Coeficiente de correlación de Pearson (Grupo 1):", coef_corr1)
print("Valor p:", valor_p1)
# Out:
# Coeficiente de correlación de Pearson (Grupo 1): -0.057133344466469324
# Valor p: 0.6935088469237538

# %% [markdown]
# Interpretación de los resultados Grupo 1
#
# 1. ¿Explicar cuál es la interpretación del coeficiente de regresión en términos de la relación entre el tiempo de estudio y las calificaciones finales?
# La pendiente negativa indica que al aumentar las horas de estudio las calificaciones tienden a disminuir, lo cual refleja una relación poco coherente en los datos.
#
# 2. ¿Cómo se interpreta el coeficiente de correlación en términos de la fuerza y dirección de la relación entre las variables?
# El coeficiente de correlación, al ser cercano a cero y negativo, muestra que la relación entre las variables es muy débil y sin una dirección definida.
# 3. ¿El modelo de regresión lineal es estadísticamente significativo?
# El modelo no resulta significativo, ya que el valor p excede el nivel de 0.05.
#
# 4. ¿Qué tan confiable es el modelo de regresión para predecir las calificaciones finales de los estudiantes basado en el tiempo de estudio?
# El modelo ofrece muy baja confiabilidad, por lo que no es útil para predecir las calificaciones finales a partir del tiempo de estudio.

# %% [markdown]
# ### Grupo 2

# %%
df2 = pd.read_csv("grupo2.csv")
df2.head()
# Out:
#    HorasEstudio  Calificacion
# 0          3.79          40.0
# 1          6.08          26.1
# 2          7.17          29.0
# 3          7.54          31.9
# 4          8.18          34.8

# %%
df2.describe()
# Out:
#        HorasEstudio  Calificacion
# count     50.000000     50.000000
# mean      14.352000     75.912000
# std        4.219174     20.668922
# min        3.790000     26.100000
# 25%       12.032500     63.500000
# 50%       14.600000     78.550000
# 75%       17.715000     93.300000
# max       20.000000     99.000000

# %%
#Histograma de las calificaciones
plt.hist(df2["Calificacion"], bins=10, color="skyblue", edgecolor="black")
plt.title("Histograma Calificaciones Grupo 2")
plt.xlabel("Calificación")
plt.ylabel("Frecuencia")
plt.show()

# %% [markdown]
# ### Modelo de Regresión Lineal

# %%
HorasGrupo2 = df2[["HorasEstudio"]]
CalificacionGrupo2 = df2["Calificacion"]

modeloGrupo2 = LinearRegression()
modeloGrupo2.fit(HorasGrupo2, CalificacionGrupo2)

print("Coeficiente de la pendiente (m):", modeloGrupo2.coef_[0])
print("Interpretación de la recta (b):", modeloGrupo2.intercept_)
# Out:
# Coeficiente de la pendiente (m): 4.222718653627889
# Interpretación de la recta (b): 15.30754188313253

# %% [markdown]
# ### Visualización de resultados
# ### Grafico de dispersión y linea de regresión

# %%
# Datos Grupo 2
df2 = pd.read_csv("grupo2.csv")
horas_estudio2 = df2["HorasEstudio"].values.reshape(-1, 1)
calificaciones2 = df2["Calificacion"].values

# Definir tamaño
plt.figure(figsize=(6, 5))

# Crear el diagrama de dispersión con línea de regresión
sns.set(style="whitegrid")
sns.regplot(x=horas_estudio2, y=calificaciones2, scatter=True, color='blue')
plt.title('Diagrama de Dispersion con Línea de Regresión')
plt.xlabel('Horas de estudio')
plt.ylabel('Califiación')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Coeficiente de correlación de Pearson

# %%
# Datos Grupo 2
df2 = pd.read_csv("grupo2.csv")
horas_estudio2 = df2["HorasEstudio"]
calificaciones2 = df2["Calificacion"]

# Calcular coeficiente de correlación de Pearson
coef_corr2, valor_p2 = pearsonr(horas_estudio2, calificaciones2)

print("Coeficiente de correlación de Pearson (Grupo 2):", coef_corr2)
print("Valor p:", valor_p2)
# Out:
# Coeficiente de correlación de Pearson (Grupo 2): 0.861989042650508
# Valor p: 9.077714233687994e-16

# %% [markdown]
# Interpretación de los resultados Grupo 2
# 1. ¿Explicar cuál es la interpretación del coeficiente de regresión en términos de la relación entre el tiempo de estudio y las calificaciones finales?
#
# La pendiente positiva refleja que por cada hora adicional de estudio, la calificación final aumenta en promedio 4.22 puntos, mostrando una relación más coherente entre las variables.
#
# 2. ¿Cómo se interpreta el coeficiente de correlación en términos de la fuerza y dirección de la relación entre las variables?
#
# El coeficiente de correlación, al ser elevado y positivo, indica una relación fuerte y directa: a mayor tiempo de estudio, mejores resultados académicos.
#
# 3. ¿El modelo de regresión lineal es estadísticamente significativo?
#
# El modelo sí presenta significancia estadística, dado que el valor p es considerablemente menor a 0.05.
#
# 4. ¿Qué tan confiable es el modelo de regresión para predecir las calificaciones finales de los estudiantes basado en el tiempo de estudio?
#
# El modelo resulta confiable, ya que permite predecir las calificaciones finales con bastante precisión a partir del tiempo dedicado al estudio.

# %% [markdown]
# ### Grupo 3

# %%
df3 = pd.read_csv("grupo3.csv")
df3.head()
# Out:
#    HorasEstudio  Calificacion
# 0          3.79          15.0
# 1          6.08          26.1
# 2          7.17          29.0
# 3          7.54          31.9
# 4          8.18          34.8

# %%
df3.describe()
# Out:
#        HorasEstudio  Calificacion
# count     50.000000     50.000000
# mean      14.352000     75.968000
# std        4.219174     23.668867
# min        3.790000     15.000000
# 25%       12.032500     61.000000
# 50%       14.600000     84.950000
# 75%       17.715000     94.375000
# max       20.000000     99.000000

# %%
#Histograma de las calificaciones
plt.hist(df3["Calificacion"], bins=10, color="skyblue", edgecolor="black")
plt.title("Histograma Calificaciones Grupo 3")
plt.xlabel("Calificación")
plt.ylabel("Frecuencia")
plt.show()

# %% [markdown]
# ### Modelo de Regresión Lineal

# %%
HorasGrupo3 = df3[["HorasEstudio"]]
CalificacionGrupo3 = df3["Calificacion"]

modeloGrupo3 = LinearRegression()
modeloGrupo3.fit(HorasGrupo3, CalificacionGrupo3)

print("Coeficiente de la pendiente (m):", modeloGrupo3.coef_[0])
print("Interpretación de la recta (b):", modeloGrupo3.intercept_)
# Out:
# Coeficiente de la pendiente (m): 5.285670950508442
# Interpretación de la recta (b): 0.10805051830283219

# %% [markdown]
# ### Visualización de resultados
# ### Grafico de dispersión y linea de regresión

# %%
# Datos Grupo 3
df3 = pd.read_csv("grupo3.csv")
horas_estudio3 = df3["HorasEstudio"].values.reshape(-1, 1)
calificaciones3 = df3["Calificacion"].values

# Definir tamaño
plt.figure(figsize=(6, 5))

# Crear el diagrama de dispersión con línea de regresión
sns.set(style="whitegrid")
sns.regplot(x=horas_estudio3, y=calificaciones3, scatter=True, color='blue')
plt.title('Diagrama de Dispersion con Línea de Regresión')
plt.xlabel('Horas de estudio')
plt.ylabel('Califiación')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Coeficiente de correlación de Pearson

# %%
# Datos Grupo 2
df3 = pd.read_csv("grupo3.csv")
horas_estudio3 = df3["HorasEstudio"]
calificaciones3 = df3["Calificacion"]

# Calcular coeficiente de correlación de Pearson
coef_corr3, valor_p3 = pearsonr(horas_estudio3, calificaciones3)

print("Coeficiente de correlación de Pearson (Grupo 3):", coef_corr3)
print("Valor p:", valor_p3)
# Out:
# Coeficiente de correlación de Pearson (Grupo 3): 0.9422151342073145
# Valor p: 1.9341524231025033e-24

# %% [markdown]
# Interpretación de los resultados Grupo 3
# 1. ¿Explicar cuál es la interpretación del coeficiente de regresión en términos de la relación entre el tiempo de estudio y las calificaciones finales?
#
# La pendiente positiva indica que por cada hora adicional de estudio, la calificación final aumenta en promedio 5.28 puntos. Al igual que en el grupo 2, la relación entre las variables es consistente y con menor variabilidad.
#
# 2. ¿Cómo se interpreta el coeficiente de correlación en términos de la fuerza y dirección de la relación entre las variables?
#
# El coeficiente de correlación, al estar muy próximo a 1, refleja una relación extremadamente fuerte y positiva entre el tiempo de estudio y las calificaciones.
#
# 3. ¿El modelo de regresión lineal es estadísticamente significativo?
#
# El modelo sí resulta altamente significativo, ya que el valor p se aproxima bastante a cero.
#
# 4. ¿Qué tan confiable es el modelo de regresión para predecir las calificaciones finales de los estudiantes basado en el tiempo de estudio?
#
# Es un modelo muy confiable, el más sólido de los tres grupos, pues al mostrar una relación más marcada permite predecir las calificaciones con gran exactitud a partir de las horas de estudio.

# %% [markdown]
# ### Conclusiones Generales
# #### En el Grupo 1 no se identificó una relación clara ni significativa, lo que hace que el modelo no sea adecuado para anticipar las calificaciones. En el Grupo 2 sí aparece una asociación positiva marcada: a mayor número de horas de estudio, mejores resultados, aunque la presencia de algunos valores atípicos disminuye ligeramente la precisión. El Grupo 3 muestra la conexión más consistente y confiable, con un modelo altamente significativo que explica casi por completo el rendimiento académico en función del tiempo dedicado al estudio. Con base en estos hallazgos, se puede afirmar que invertir más horas en estudiar favorece el desempeño escolar; sin embargo, también influyen otros aspectos como la calidad del aprendizaje, la motivación y las estrategias utilizadas, lo que explica las diferencias en los rangos de calificación entre los grupos.
