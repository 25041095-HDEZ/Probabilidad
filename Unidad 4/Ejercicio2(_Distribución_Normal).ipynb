# %% [markdown]
# <a href="https://colab.research.google.com/github/25041095-HDEZ/Probabilidad/blob/main/Unidad%204/Ejercicio2(_Distribuci%C3%B3n_Normal).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
plt.figure(figsize=(6, 4))

# Parámetros de la distribución normal
media = 70 # Media
desv_std = 4 #Desviación estándar
total_estudiantes = 500

# VARIABLE para Cálculo de la probabilidad de que un estudiante que pese menos de 75 kg
peso_limite = 75

# Primero necesitamos calcular la probabilidad de que un estudiante pese menos
# de 75 kg utilizando La función de distribucion acumulativa (CFD) de la distribucion normal
prob_menos_75kg = norm.cdf(peso_limite, media, desv_std)

# %%
# Calculo del numero de estudiantes que pesan menos de 75 kg
estudiantes_menos_75kg = total_estudiantes * prob_menos_75kg

print("Probabilidad de que un estudiante pese menos de 75 kg:", prob_menos_75kg)
print("Número de estudiantes que pesan menos de 75 kg:", estudiantes_menos_75kg)

x = np.linspace(media - 4 * desv_std, media + 4 * desv_std, 1000)
y = norm.pdf(x, media, desv_std)

plt.plot(x, y, 'b', linewidth=2)
plt.fill_between(x, y, where=(x <= peso_limite), color='skyblue', alpha=0.5)
plt.title('Probabilidad de que unn estudiante pese menos de 75 kg. \n $\mu=70$, $\sigma=4$, x=500')
plt.xlabel('Peso (kg)')
plt.ylabel('Densidad de probabilidad')
plt.grid(True)
plt.show()
# Out:
# <>:12: SyntaxWarning: invalid escape sequence '\m'
# <>:12: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipykernel_2890/3333629713.py:12: SyntaxWarning: invalid escape sequence '\m'
#   plt.title('Probabilidad de que unn estudiante pese menos de 75 kg. \n $\mu=70$, $\sigma=4$, x=500')
# Probabilidad de que un estudiante pese menos de 75 kg: 0.8943502263331446
# Número de estudiantes que pesan menos de 75 kg: 447.1751131665723

# %%
plt.figure(figsize=(6, 4))

media = 70
desv_std = 4
total_estudiantes = 500

peso_limite = 62

prob_menos_62kg = norm.cdf(peso_limite, media, desv_std)

estudiantes_menos_62kg = total_estudiantes * prob_menos_62kg

print("Probabilidad de que un estudiante pese menos de 62 kg:", prob_menos_62kg)
print("Número de estudiantes que pesan menos de 75 kg:", estudiantes_menos_62kg)
# Out:
# Probabilidad de que un estudiante pese menos de 62 kg: 0.022750131948179195
# Número de estudiantes que pesan menos de 75 kg: 11.375065974089598

# %%
x = np.linspace(media - 4 * desv_std, media + 4 * desv_std, total_estudiantes)
y = norm.pdf(x, media, desv_std)

plt.plot(x, y, 'b', linewidth=2)
plt.fill_between(x, y, where=(x <= peso_limite), color='skyblue', alpha=0.5)
plt.title('Probabilidad de que unn estudiante pese menos de 62 kg. \n $\mu=70$, $\sigma=4$, x=500')
plt.xlabel('Peso (kg)')
plt.ylabel('Densidad de probabilidad')
plt.grid(True)
plt.show()
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\m'
# <>:6: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipykernel_2890/694039307.py:6: SyntaxWarning: invalid escape sequence '\m'
#   plt.title('Probabilidad de que unn estudiante pese menos de 62 kg. \n $\mu=70$, $\sigma=4$, x=500')

# %%
plt.figure(figsize=(6, 4))

media = 70
desv_std = 4
peso_limite = 79
total_estudiantes = 500

prob_menos_79kg = norm.cdf(peso_limite, media, desv_std)

prob_mas_79kg = 1 - prob_menos_79kg

estudiantes_mas_79kg = total_estudiantes * prob_mas_79kg

print("Probabilidad de que un estudiante pese mas de 79 kg:", prob_mas_79kg)
print("Número de estudiantes que pesen mas de 79 kg:", estudiantes_mas_79kg)

x = np.linspace(media - 4 * desv_std, media + 4 * desv_std, total_estudiantes)
y = norm.pdf(x, media, desv_std)

plt.plot(x, y, 'b', linewidth=2)
plt.fill_between(x, y, where=(x <= peso_limite), color='skyblue', alpha=0.5)
plt.title('Probabilidad de que unn estudiante pese mas de 79 kg. \n $\mu=70$, $\sigma=4$, x=500')
plt.xlabel('Peso (kg)')
plt.ylabel('Densidad de probabilidad')
plt.grid(True)
plt.show()
# Out:
# Probabilidad de que un estudiante pese mas de 79 kg: 0.012224472655044671
# Número de estudiantes que pesen mas de 79 kg: 6.112236327522336
# <>:22: SyntaxWarning: invalid escape sequence '\m'
# <>:22: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipykernel_2890/3504676347.py:22: SyntaxWarning: invalid escape sequence '\m'
#   plt.title('Probabilidad de que unn estudiante pese mas de 79 kg. \n $\mu=70$, $\sigma=4$, x=500')
