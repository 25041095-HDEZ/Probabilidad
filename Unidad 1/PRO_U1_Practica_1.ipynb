# %% [markdown]
# <a href="https://colab.research.google.com/github/25041095-HDEZ/Probabilidad/blob/main/Unidad%201/PRO_U1_Practica_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y Estadistica
#
# ## Unidad 1
#
# ### Facilitador: Jose Gabriel Rodriguez Rivas
#
# ### Alumno________________________________
#
# ### **Prograna 1: Estadistica basica e Histogramas**

# %%
from statistics import *

# %% [markdown]
# #Ejemplo 1

# %%
# Lista de calificaciones del grupo A de probabilidad y estadistica
GrupoA = [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]
print(GrupoA)
type(GrupoA)
# Out:
# [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]
# list

# %%
# Sacar la media de las calificaciones con una formula
promedio = sum(GrupoA) / len(GrupoA)
print(promedio)
# Out:
# 75.33333333333333

# %%
#Utilizar la funcion mean que esta en la libreria statistics para sacar
# el promedio
promedio2 =mean(GrupoA)
print(promedio2)
# Out:
# 75.33333333333333

# %%
# Determina el valor de la media con la funcion median

mediana = median(GrupoA)
print(mediana)
# Out:
# 76.5

# %%
# Determina el valor de la moda con la funcion mode

moda = mode(GrupoA)
print(moda)
# Out:
# 70

# %%
#En caso de que exista mas de una moda, se puede completar la funcion multimode para sacar
# Multiples modas que pueden existir
moda2 = multimode(GrupoA)
print(moda2)
# Out:
# [70, 100]

# %%
# Definimos una variable llamada tiempos100mts de tipo lista, que contienen los
# tiempos que tardaron los 10 alumnos para correr los 100 metros
tiempos100mts =[15.10, 20.43, 65.20, 22.90, 56.33, 33.33, 11.11, 77.00,
                44.44, 16.16]

# Desplegamos los valores de la lista
print(tiempos100mts)
# Out:
# [15.1, 20.43, 65.2, 22.9, 56.33, 33.33, 11.11, 77.0, 44.44, 16.16]

# %% [markdown]
# #**Funcion Mean para calcular el promedio**

# %%
# Usamos la funcion mean para deternminar el tiempo promedio de la lista de valores

print("El tiempo promedio de los corredores es=>", mean(tiempos100mts) )
print("El tiempo promedio de los corredores es=>", median(tiempos100mts) )
print("El tiempo promedio de los corredores es=>", mode(tiempos100mts) )
# Out:
# El tiempo promedio de los corredores es=> 36.2
# El tiempo promedio de los corredores es=> 28.115
# El tiempo promedio de los corredores es=> 15.1

# %% [markdown]
# #**Ejemplo3: Histograma de 2 Grupos**

# %%
# Libreria para generar numeros aleatorios
import random

# %%
fabrica1 = []
for i in range(100):
    numero_aleatorio = round(random.uniform(50, 100), 2)
    fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [98.72, 95.46, 93.86, 60.38, 51.21, 97.43, 76.97, 70.3, 75.29, 63.85, 84.27, 58.24, 59.13, 94.33, 70.59, 74.89, 84.4, 65.12, 60.09, 58.77, 96.64, 75.42, 93.33, 57.86, 57.07, 92.39, 92.38, 88.53, 91.5, 77.52, 94.69, 62.63, 69.01, 89.27, 58.06, 86.71, 73.69, 87.8, 84.09, 91.5, 97.39, 86.78, 52.51, 68.97, 69.74, 92.97, 94.58, 60.15, 78.66, 75.73, 67.74, 59.04, 95.47, 58.57, 67.08, 72.85, 91.05, 54.45, 89.84, 53.25, 91.55, 79.2, 76.21, 93.94, 79.5, 69.77, 51.43, 65.03, 53.84, 69.2, 54.1, 55.12, 51.43, 99.58, 65.32, 82.54, 60.2, 65.5, 54.92, 52.36, 74.41, 77.71, 80.2, 93.86, 68.87, 82.29, 70.19, 68.1, 98.71, 61.51, 67.1, 90.14, 97.07, 96.77, 52.11, 55.71, 96.16, 74.42, 70.22, 82.93]

# %%
fabrica2 = []
for i in range(100):
    numero_aleatorio = round(random.uniform(70, 100), 2)
    fabrica2.append(numero_aleatorio)
print(fabrica2)
# Out:
# [96.26, 72.62, 73.06, 93.16, 96.04, 93.52, 94.22, 79.21, 85.28, 84.61, 83.12, 77.68, 82.97, 80.83, 73.31, 79.1, 97.91, 70.61, 76.25, 75.31, 72.49, 85.53, 93.02, 82.95, 87.37, 84.32, 71.98, 75.81, 99.39, 91.75, 79.89, 76.68, 73.1, 75.3, 91.04, 85.46, 96.17, 91.28, 94.27, 70.43, 88.71, 81.41, 90.51, 83.8, 76.71, 78.81, 81.73, 81.91, 96.54, 92.2, 94.06, 95.41, 75.8, 97.9, 73.59, 93.98, 73.64, 83.06, 91.44, 84.1, 76.16, 86.11, 85.37, 80.86, 70.83, 76.9, 85.83, 83.47, 87.87, 93.84, 98.18, 75.07, 72.59, 72.79, 93.34, 88.01, 96.63, 94.0, 72.55, 72.14, 76.66, 84.89, 75.54, 81.1, 99.38, 99.62, 97.48, 78.92, 71.78, 82.02, 80.55, 99.28, 72.51, 85.47, 89.24, 92.54, 93.22, 82.97, 98.76, 75.65]

# %%
# libreria de python para graficar valores
import matplotlib.pyplot as plt

# %%
plt.hist(fabrica1)
plt.title("Produccion diaria de la fabrica1")

(0.5, 1.0, "Produccion diaria de la fabrica1")
# Out:
# (0.5, 1.0, 'Produccion diaria de la fabrica1')

# %%
plt.hist(fabrica2)
plt.title("Produccion diaria de la fabrica2")

(0.5, 1.0, "Produccion diaria de la fabrica2")
# Out:
# (0.5, 1.0, 'Produccion diaria de la fabrica2')

# %%
media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 =mode(fabrica1)

print("Valores de la fabrica1")
print("La media es =", media1)
print("La mediana es =", mediana1)
print("La moda es =", moda1)
# Out:
# Valores de la fabrica1
# La media es = 75.29429999999999
# La mediana es = 74.655
# La moda es = 93.86

# %%
media1 = mean(fabrica2)
mediana1 = median(fabrica2)
moda1 =mode(fabrica2)

print("Valores de la fabrica2")
print("La media es =", media1)
print("La mediana es =", mediana1)
print("La moda es =", moda1)
# Out:
# Valores de la fabrica2
# La media es = 84.3873
# La mediana es = 83.63499999999999
# La moda es = 82.97

# %%
# generar 2 subplot de 1 renglon por 2 columnas para desplegar los 2 histogramas
#una al lado de otra
fig, (ax1, ax2) = plt.subplots(nrows =1, ncols =2, figsize=(10, 5))
ax1.hist(fabrica1)
ax2.hist(fabrica2)
plt.show()
