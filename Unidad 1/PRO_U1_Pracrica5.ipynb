# %% [markdown]
# <a href="https://colab.research.google.com/github/25041095-HDEZ/Probabilidad/blob/main/Unidad%201/PRO_U1_Pracrica5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns
from matplotlib import pyplot

# %%
covid = pd.read_csv("Covid.csv", encoding = "ISO-8859-1")

# %%
covid.head()
# Out:
#                                                                            ca  \
# 1 12 Mujer  M̩xico Hospitalizado 24/06/2020 20/06/2020 9999-99-99         No
# 2 12 Mujer  M̩xico Ambulatorio   25/06/2020 20/06/2020 9999-99-99  No aplica
#      Hombre M̩xico Ambulatorio   20/06/2020 20/06/2020 9999-99-99  No aplica
#   3  Mujer  M̩xico Ambulatorio   23/06/2020 20/06/2020 9999-99-99  No aplica
#   4  Mujer  M̩xico Ambulatorio   23/06/2020 20/06/2020 9999-99-99  No aplica
#
#                                                                     No    32  \
# 1 12 Mujer  M̩xico Hospitalizado 24/06/2020 20/06/2020 9999-99-99  No  32.0
# 2 12 Mujer  M̩xico Ambulatorio   25/06/2020 20/06/2020 9999-99-99  No  32.0
#      Hombre M̩xico Ambulatorio   20/06/2020 20/06/2020 9999-99-99  No  32.0
#   3  Mujer  M̩xico Ambulatorio   23/06/2020 20/06/2020 9999-99-99  No  32.0
#   4  Mujer  M̩xico Ambulatorio   23/06/2020 20/06/2020 9999-99-99  No  32.0
#
#                                                                     No aplica  \
# 1 12 Mujer  M̩xico Hospitalizado 24/06/2020 20/06/2020 9999-99-99         No
# 2 12 Mujer  M̩xico Ambulatorio   25/06/2020 20/06/2020 9999-99-99         No
#      Hombre M̩xico Ambulatorio   20/06/2020 20/06/2020 9999-99-99  No aplica
#   3  Mujer  M̩xico Ambulatorio   23/06/2020 20/06/2020 9999-99-99         No
#   4  Mujer  M̩xico Ambulatorio   23/06/2020 20/06/2020 9999-99-99         No
#
#                                                                    No.1 No.2  \
# 1 12 Mujer  M̩xico Hospitalizado 24/06/2020 20/06/2020 9999-99-99   No   No
# 2 12 Mujer  M̩xico Ambulatorio   25/06/2020 20/06/2020 9999-99-99   No   No
#      Hombre M̩xico Ambulatorio   20/06/2020 20/06/2020 9999-99-99   No   No
#   3  Mujer  M̩xico Ambulatorio   23/06/2020 20/06/2020 9999-99-99   No   No
#   4  Mujer  M̩xico Ambulatorio   23/06/2020 20/06/2020 9999-99-99   No   No
#
#                                                                    No.3 No.4  \
# 1 12 Mujer  M̩xico Hospitalizado 24/06/2020 20/06/2020 9999-99-99   No   No
# 2 12 Mujer  M̩xico Ambulatorio   25/06/2020 20/06/2020 9999-99-99   No   No
#      Hombre M̩xico Ambulatorio   20/06/2020 20/06/2020 9999-99-99   No   No
#   3  Mujer  M̩xico Ambulatorio   23/06/2020 20/06/2020 9999-99-99   No   No
#   4  Mujer  M̩xico Ambulatorio   23/06/2020 20/06/2020 9999-99-99   No   No
#
#                                                                    No.5 No.6  \
# 1 12 Mujer  M̩xico Hospitalizado 24/06/2020 20/06/2020 9999-99-99   No   No
# 2 12 Mujer  M̩xico Ambulatorio   25/06/2020 20/06/2020 9999-99-99   No   No
#      Hombre M̩xico Ambulatorio   20/06/2020 20/06/2020 9999-99-99   No   No
#   3  Mujer  M̩xico Ambulatorio   23/06/2020 20/06/2020 9999-99-99   No   No
#   4  Mujer  M̩xico Ambulatorio   23/06/2020 20/06/2020 9999-99-99   No   No
#
#                                                                    No.7 No.8  \
# 1 12 Mujer  M̩xico Hospitalizado 24/06/2020 20/06/2020 9999-99-99   No   No
# 2 12 Mujer  M̩xico Ambulatorio   25/06/2020 20/06/2020 9999-99-99   No   No
#      Hombre M̩xico Ambulatorio   20/06/2020 20/06/2020 9999-99-99   No   No
#   3  Mujer  M̩xico Ambulatorio   23/06/2020 20/06/2020 9999-99-99   No   No
#   4  Mujer  M̩xico Ambulatorio   23/06/2020 20/06/2020 9999-99-99   No   No
#
#                                                                    No.9  \
# 1 12 Mujer  M̩xico Hospitalizado 24/06/2020 20/06/2020 9999-99-99   No
# 2 12 Mujer  M̩xico Ambulatorio   25/06/2020 20/06/2020 9999-99-99   Si
#      Hombre M̩xico Ambulatorio   20/06/2020 20/06/2020 9999-99-99   No
#   3  Mujer  M̩xico Ambulatorio   23/06/2020 20/06/2020 9999-99-99   No
#   4  Mujer  M̩xico Ambulatorio   23/06/2020 20/06/2020 9999-99-99   No
#
#                                                                            3  \
# 1 12 Mujer  M̩xico Hospitalizado 24/06/2020 20/06/2020 9999-99-99  Positivo
# 2 12 Mujer  M̩xico Ambulatorio   25/06/2020 20/06/2020 9999-99-99  Positivo
#      Hombre M̩xico Ambulatorio   20/06/2020 20/06/2020 9999-99-99  Positivo
#   3  Mujer  M̩xico Ambulatorio   23/06/2020 20/06/2020 9999-99-99  Positivo
#   4  Mujer  M̩xico Ambulatorio   23/06/2020 20/06/2020 9999-99-99  Positivo
#
#                                                                    No aplica.1
# 1 12 Mujer  M̩xico Hospitalizado 24/06/2020 20/06/2020 9999-99-99          No
# 2 12 Mujer  M̩xico Ambulatorio   25/06/2020 20/06/2020 9999-99-99   No aplica
#      Hombre M̩xico Ambulatorio   20/06/2020 20/06/2020 9999-99-99   No aplica
#   3  Mujer  M̩xico Ambulatorio   23/06/2020 20/06/2020 9999-99-99   No aplica
#   4  Mujer  M̩xico Ambulatorio   23/06/2020 20/06/2020 9999-99-99   No aplica

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 23464 entries, (np.int64(1), np.int64(12), 'Mujer', 'M̩xico', 'Hospitalizado', '24/06/2020', '20/06/2020', '9999-99-99') to (np.int64(2), np.int64(12), 'Hombre', 'M̩xico', 'Ambulatorio', '16/06/', nan, nan)
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ca           23463 non-null  object
#  1   No           23463 non-null  object
#  2   32           23463 non-null  float64
#  3   No aplica    23463 non-null  object
#  4   No.1         23463 non-null  object
#  5   No.2         23463 non-null  object
#  6   No.3         23463 non-null  object
#  7   No.4         23463 non-null  object
#  8   No.5         23463 non-null  object
#  9   No.6         23463 non-null  object
#  10  No.7         23463 non-null  object
#  11  No.8         23463 non-null  object
#  12  No.9         23463 non-null  object
#  13  3            23463 non-null  object
#  14  No aplica.1  23463 non-null  object
# dtypes: float64(1), object(14)
# memory usage: 2.9+ MB
