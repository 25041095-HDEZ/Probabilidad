# %% [markdown]
# <a href="https://colab.research.google.com/github/25041095-HDEZ/Probabilidad/blob/main/Unidad%201/PRO_U1_Pracrica4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import matplotlib.pyplot as plt
from statistics import *

# %%
fabrica1 = []
for i in range(100):
  numero_aleatorio = round( random.uniform(50, 100), 2 )
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [82.85, 63.07, 57.7, 52.22, 58.31, 76.15, 66.86, 97.71, 62.81, 63.97, 86.95, 90.52, 94.28, 60.05, 89.79, 79.57, 59.64, 86.44, 81.85, 64.34, 59.78, 76.99, 91.58, 84.22, 61.34, 91.31, 83.73, 73.31, 74.35, 99.93, 93.68, 52.31, 95.76, 94.26, 98.56, 66.99, 87.36, 50.61, 66.85, 82.01, 96.33, 71.92, 75.46, 78.85, 83.47, 58.33, 66.87, 65.91, 65.43, 69.97, 66.94, 94.73, 94.02, 80.93, 78.5, 78.17, 77.33, 86.03, 87.99, 69.67, 89.77, 57.83, 77.61, 66.23, 70.2, 98.12, 69.59, 68.88, 84.57, 60.22, 80.5, 83.84, 95.22, 64.74, 77.59, 58.26, 62.33, 94.57, 66.81, 90.46, 81.9, 72.25, 90.38, 56.96, 53.58, 86.7, 79.2, 98.32, 64.57, 68.85, 89.68, 92.66, 81.78, 79.09, 88.53, 70.65, 84.01, 92.11, 73.04, 95.93]

# %%
fabrica2 = []
for i in range(100):
  numero_aleatorio = round( random.uniform(50, 100), 2 )
  fabrica2.append(numero_aleatorio)
print(fabrica2)
# Out:
# [92.79, 50.26, 58.76, 73.81, 59.48, 94.58, 94.59, 91.47, 79.34, 78.27, 72.98, 72.4, 81.17, 75.54, 94.56, 95.6, 72.93, 86.25, 65.08, 70.48, 66.34, 76.41, 72.0, 84.85, 54.13, 54.65, 93.38, 96.45, 61.68, 94.16, 86.14, 72.06, 51.6, 63.62, 66.11, 88.4, 74.39, 88.48, 76.47, 67.49, 99.68, 94.16, 76.48, 67.99, 70.85, 50.92, 60.23, 88.86, 84.64, 89.29, 67.52, 75.43, 50.95, 90.65, 71.97, 96.96, 68.6, 77.29, 50.82, 97.16, 52.29, 61.41, 92.57, 57.96, 98.29, 72.28, 88.5, 94.85, 91.57, 62.32, 57.63, 97.83, 90.51, 57.11, 53.21, 63.34, 69.41, 85.48, 72.22, 78.66, 88.78, 64.26, 62.54, 87.54, 93.2, 57.31, 73.2, 64.75, 52.71, 57.87, 50.36, 76.05, 75.75, 54.83, 72.81, 90.38, 56.36, 73.58, 79.85, 93.73]

# %%
plt.boxplot(fabrica1)
plt.ylabel('Produccion en mts.')
plt.title('Produccion de la fabrica 1')
plt.show()

# %%
plt.boxplot(fabrica2)
plt.ylabel('Produccion en mts.')
plt.title('Produccion de la fabrica 1')
plt.show()

# %% [markdown]
# ###*Comparamos la produccion de la fabrica 1 y 2 en un subplot*

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))
bplot1 = ax1.boxplot(fabrica1,
                     vert=True, #Alineacion Vertical
                     patch_artist=True) #Rellenar con color
ax1.set_title('Produccion fabrica 1')

bplot2 = ax2.boxplot(fabrica2,
                     vert=True, #Alineacion Vertical
                     patch_artist=True) #Rellenar con color

ax2.set_title('Produccion fabrica 2')
plt.show()

# %%
#insertamos un valor de 150 a la fabrica 1,
#Seria un valor atipico

fabrica1.append(150)
print(fabrica1)
# Out:
# [82.85, 63.07, 57.7, 52.22, 58.31, 76.15, 66.86, 97.71, 62.81, 63.97, 86.95, 90.52, 94.28, 60.05, 89.79, 79.57, 59.64, 86.44, 81.85, 64.34, 59.78, 76.99, 91.58, 84.22, 61.34, 91.31, 83.73, 73.31, 74.35, 99.93, 93.68, 52.31, 95.76, 94.26, 98.56, 66.99, 87.36, 50.61, 66.85, 82.01, 96.33, 71.92, 75.46, 78.85, 83.47, 58.33, 66.87, 65.91, 65.43, 69.97, 66.94, 94.73, 94.02, 80.93, 78.5, 78.17, 77.33, 86.03, 87.99, 69.67, 89.77, 57.83, 77.61, 66.23, 70.2, 98.12, 69.59, 68.88, 84.57, 60.22, 80.5, 83.84, 95.22, 64.74, 77.59, 58.26, 62.33, 94.57, 66.81, 90.46, 81.9, 72.25, 90.38, 56.96, 53.58, 86.7, 79.2, 98.32, 64.57, 68.85, 89.68, 92.66, 81.78, 79.09, 88.53, 70.65, 84.01, 92.11, 73.04, 95.93, 150]

# %%
fig, (ax1, ax2)=plt.subplots(nrows=1, ncols=2, figsize=(9, 4))
bplot1=ax1.boxplot(fabrica1,
                     vert=True, #Alineacion Vertical
                     patch_artist=True) #Rellenar con color
ax1.set_title('Produccion fabrica 1')

bplot2=ax2.boxplot(fabrica2,
                     vert=True, #Alineacion Vertical
                     patch_artist=True) #Rellenar con color

ax2.set_title('Produccion fabrica 2')
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))
bplot1 = ax1.boxplot(fabrica1,
                     vert=True, #Alineacion Vertical
                     patch_artist=True) #Rellenar con color
ax1.set_title('Produccion fabrica 1')
ax1.set_ylim(30, 160) # Escala Uniforme de 0 a 160

bplot2 = ax2.boxplot(fabrica2,
                     vert=True, #Alineacion Vertical
                     patch_artist=True) #Rellenar con color

ax2.set_title('Produccion fabrica 2')
ax2.set_ylim(30, 160) #Escala Uniforme de 0 a 160
plt.show()
